# %%
# !pip install numpy
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 985.5 kB/s eta 0:00:13
#    -- ------------------------------------- 0.8/12.6 MB 1.1 MB/s eta 0:00:11
#    --- ------------------------------------ 1.0/12.6 MB 1.1 MB/s eta 0:00:11
#    --- ------------------------------------ 1.0/12.6 MB 1.1 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.3/12.6 MB 1.0 MB/s eta 0:00:12
#    ----- ---------------------------------- 1.8/12.6 MB 1.1 MB/s eta 0:00:10
#    ------ --------------------------------- 2.1/12.6 MB 1.2 MB/s eta 0:00:09
#    ------- -------------------------------- 2.4/12.6 MB 1.2 MB/s eta 0:00:09
# ...

# %%
import numpy as np
import pandas as pd
